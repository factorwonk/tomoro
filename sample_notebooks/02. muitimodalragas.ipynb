# %%
import json
import os
from tqdm import tqdm
from typing import List, Dict
from datasets import Dataset
from ragas.metrics import (
    faithfulness,
    answer_relevancy,
    context_recall,
    context_precision,
    context_entity_recall,
    answer_similarity,
    answer_correctness
)
from ragas import evaluate
from langchain.schema import Document
from langchain.chat_models import ChatOpenAI
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain_chroma import Chroma
from dotenv import load_dotenv
from openai import OpenAI
from operator import itemgetter
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
from langchain_core.runnables import RunnablePassthrough

# %%
# Load environment variables
load_dotenv(override=True)
client = OpenAI(api_key=os.environ['OPENAI_API_KEY'])

# %% [markdown]
# ### RAG Helper Function
# ---

# %%
def process_documents(json_data: List[Dict], target_samples: int = 100):
    """Process documents until we get exactly target_samples valid QA pairs"""
    queries = []
    ground_truths = []
    documents = []
    valid_count = 0
    
    print(f"Processing documents to find {target_samples} valid samples...")
    for entry in tqdm(json_data):
        # Check for valid QA data
        if entry.get("qa"):
            qa_data = entry["qa"]
            if isinstance(qa_data, dict) and "question" in qa_data and "answer" in qa_data:
                # Process the valid QA pair
                queries.append(qa_data["question"])
                answer = qa_data["answer"]
                if isinstance(answer, list):
                    ground_truths.append(answer[0])
                else:
                    ground_truths.append(answer)
                
                # Process document content
                doc_content = []
                if entry.get("pre_text"):
                    doc_content.extend(entry["pre_text"])
                if entry.get("table_ori"):
                    table_str = "\n".join(" | ".join(str(cell) for cell in row) for row in entry["table_ori"])
                    doc_content.append(table_str)
                if entry.get("post_text"):
                    doc_content.extend(entry["post_text"])
                
                documents.append(Document(
                    page_content="\n".join(doc_content),
                    metadata={"id": entry.get("id")}
                ))
                
                valid_count += 1
                if valid_count == target_samples:
                    break
    
    print(f"Found {valid_count} valid samples after processing {len(json_data)} documents")
    
    if valid_count < target_samples:
        raise ValueError(f"Could only find {valid_count} valid samples, but {target_samples} were requested")
    
    return queries, ground_truths, documents

# %%
def setup_rag_chain(documents):
    """Set up the RAG chain using RetrievalQA"""
    # Initialize models and vectorstore
    embedding_model = OpenAIEmbeddings(model="text-embedding-3-small")
    llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)
    
    # Initialize Chroma vectorstore
    vectorstore = Chroma(
        collection_name="text_table_rag",
        embedding_function=embedding_model
    )
    
    # Add documents to vectorstore
    vectorstore.add_documents(documents)
    
    # Create prompt template
    PROMPT_TEMPLATE = """
    Go through the context and answer the given question strictly based on context.
    Use two sentences maximum and keep the answer concise.
    
    Context: {context}
    Question: {question}
    Answer:
    """
    
    # Create RetrievalQA chain
    qa_chain = RetrievalQA.from_chain_type(
        llm=llm,
        retriever=vectorstore.as_retriever(),
        return_source_documents=True,
        chain_type_kwargs={"prompt": PromptTemplate.from_template(PROMPT_TEMPLATE)}
    )
    
    return qa_chain

# %%
def evaluate_rag_pipeline(qa_chain, queries: List[str], ground_truths: List[str]):
    """Evaluate the RAG pipeline using RAGAS metrics"""
    results = []
    contexts = []
    
    print("Generating answers and collecting contexts...")
    for query in tqdm(queries):
        # Get response from RAG chain
        result = qa_chain({"query": query})
        results.append(result['result'])
        
        # Get contexts
        sources = result["source_documents"]
        contents = [source.page_content for source in sources]
        contexts.append(contents)
    
    # Prepare data for RAGAS evaluation
    data = {
        "question": queries,
        "answer": results,
        "contexts": contexts,
        "ground_truth": ground_truths  # Note: changed from ground_truths to ground_truth to match RAGAS expectations
    }
    
    # Create dataset and evaluate
    dataset = Dataset.from_dict(data)
    score = evaluate(
        dataset=dataset,
        metrics=[
            faithfulness,
            answer_relevancy,
            context_precision,
            context_recall,
            context_entity_recall,
            answer_similarity,
            answer_correctness
        ]
    )
    
    return score, results

# %%
def main():
    # Load data
    print("Loading data...")
    with open('./data/convfinqatrain.json', 'r') as f:
        json_data = json.load(f)
    
    # Process documents
    print("Processing documents...")
    queries, ground_truths, documents = process_documents(json_data, target_samples=100)
    print(f"Processed {len(queries)} questions and documents")
    
    # Setup RAG chain
    print("\nSetting up RAG pipeline...")
    qa_chain = setup_rag_chain(documents)
    
    # Evaluate the pipeline
    print("\nEvaluating RAG pipeline...")
    score, generated_answers = evaluate_rag_pipeline(qa_chain, queries, ground_truths)
    
    # Print results
    print("\nEvaluation Results:")
    score_df = score.to_pandas()
    print(score_df)
    
    # Save results
    score_df.to_csv("EvaluationScores.csv", encoding="utf-8", index=False)
    
    # Print mean scores
    metrics_to_average = [
        'faithfulness',
        'answer_relevancy', 
        'context_precision', 
        'context_recall',
        'context_entity_recall', 
        'semantic_similarity', 
        'answer_correctness'
    ]
    print("\nMean Scores:")
    print(score_df[metrics_to_average].mean(axis=0))
    
    # Print detailed comparison
    print("\nDetailed Comparison:")
    for i, (query, ground_truth, generated) in enumerate(zip(queries, ground_truths, generated_answers), 1):
        print(f"\nExample {i}:")
        print(f"Query: {query}")
        print(f"Ground Truth: {ground_truth}")
        print(f"Generated: {generated}")
        print("-" * 80)
    
    return score_df

# %%
if __name__ == "__main__":
    results = main()
# Out:
# Loading data...
# Processing documents...
# Processing documents to find 100 valid samples...
#   4%|▍         | 131/3037 [00:00<00:00, 154297.62it/s]
# Found 100 valid samples after processing 3037 documents
# Processed 100 questions and documents
#
# Setting up RAG pipeline...
# Evaluating RAG pipeline...
# Generating answers and collecting contexts...
# 100%|██████████| 100/100 [05:00<00:00,  3.01s/it]
# Evaluating:   0%|          | 0/700 [00:00<?, ?it/s]
# Exception raised in Job[119]: RateLimitError(Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-saeSWFy7xaaLxaQqs0dGYL2n on tokens per min (TPM): Limit 200000, Used 195644, Requested 6102. Please try again in 523ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}})
# Exception raised in Job[81]: RateLimitError(Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-saeSWFy7xaaLxaQqs0dGYL2n on tokens per min (TPM): Limit 200000, Used 194750, Requested 6040. Please try again in 237ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}})
# Exception raised in Job[122]: RateLimitError(Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-saeSWFy7xaaLxaQqs0dGYL2n on tokens per min (TPM): Limit 200000, Used 195112, Requested 6103. Please try again in 364ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}})
# Exception raised in Job[87]: RateLimitError(Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-saeSWFy7xaaLxaQqs0dGYL2n on tokens per min (TPM): Limit 200000, Used 198389, Requested 5498. Please try again in 1.166s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}})
# Exception raised in Job[88]: TimeoutError()
# Exception raised in Job[158]: RateLimitError(Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-saeSWFy7xaaLxaQqs0dGYL2n on tokens per min (TPM): Limit 200000, Used 196750, Requested 4604. Please try again in 406ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}})
# Exception raised in Job[175]: RateLimitError(Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-saeSWFy7xaaLxaQqs0dGYL2n on tokens per min (TPM): Limit 200000, Used 196003, Requested 6465. Please try again in 740ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}})
# Exception raised in Job[136]: TimeoutError()
# Exception raised in Job[192]: TimeoutError()
# Exception raised in Job[241]: RateLimitError(Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-saeSWFy7xaaLxaQqs0dGYL2n on tokens per min (TPM): Limit 200000, Used 199458, Requested 5538. Please try again in 1.498s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}})
# Exception raised in Job[266]: RateLimitError(Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-saeSWFy7xaaLxaQqs0dGYL2n on tokens per min (TPM): Limit 200000, Used 195535, Requested 6237. Please try again in 531ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}})
# Exception raised in Job[298]: RateLimitError(Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-saeSWFy7xaaLxaQqs0dGYL2n on tokens per min (TPM): Limit 200000, Used 195654, Requested 5953. Please try again in 482ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}})
# Exception raised in Job[315]: RateLimitError(Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-saeSWFy7xaaLxaQqs0dGYL2n on tokens per min (TPM): Limit 200000, Used 198378, Requested 5116. Please try again in 1.048s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}})
# Exception raised in Job[291]: RateLimitError(Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-saeSWFy7xaaLxaQqs0dGYL2n on tokens per min (TPM): Limit 200000, Used 195445, Requested 5225. Please try again in 201ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}})
# Exception raised in Job[297]: RateLimitError(Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-saeSWFy7xaaLxaQqs0dGYL2n on tokens per min (TPM): Limit 200000, Used 199633, Requested 6254. Please try again in 1.766s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}})
# Exception raised in Job[409]: RateLimitError(Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-saeSWFy7xaaLxaQqs0dGYL2n on tokens per min (TPM): Limit 200000, Used 199028, Requested 6248. Please try again in 1.582s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}})
# Exception raised in Job[392]: RateLimitError(Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-saeSWFy7xaaLxaQqs0dGYL2n on tokens per min (TPM): Limit 200000, Used 199277, Requested 5724. Please try again in 1.5s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}})
# Exception raised in Job[395]: TimeoutError()
# Exception raised in Job[476]: RateLimitError(Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-saeSWFy7xaaLxaQqs0dGYL2n on tokens per min (TPM): Limit 200000, Used 196194, Requested 6126. Please try again in 696ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}})
# Exception raised in Job[479]: RateLimitError(Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-saeSWFy7xaaLxaQqs0dGYL2n on tokens per min (TPM): Limit 200000, Used 197055, Requested 6149. Please try again in 961ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}})
# Exception raised in Job[480]: TimeoutError()
# Exception raised in Job[549]: RateLimitError(Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-saeSWFy7xaaLxaQqs0dGYL2n on tokens per min (TPM): Limit 200000, Used 197813, Requested 5714. Please try again in 1.058s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}})
# Exception raised in Job[550]: RateLimitError(Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-saeSWFy7xaaLxaQqs0dGYL2n on tokens per min (TPM): Limit 200000, Used 198313, Requested 5424. Please try again in 1.121s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}})
# Exception raised in Job[514]: TimeoutError()
# Evaluation Results:
#                                            user_input  \
# 0   what was the percentage change in the net cash...
# 1   what was the percent of the growth in the reve...
# 2   what was the percentage change in net sales fr...
# 3   what was the difference in percentage cumulati...
# 4   what portion of the total shares subject to ou...
# ..                                                ...
# 95  what were 2001 total segment revenues in billi...
# 96  what is the rate of return of an investment in...
# 97  what was the percentage change in the reserve ...
# 98  with 2014 closing stock price , what is the to...
# 99  what was the percentage cumulative total share...
#
#                                    retrieved_contexts  \
# 0   ar201122064257 positions which were requir...
# 1   [table of contents research and development ex...
# 2   [in a new business model such as the retail se...
# 3   [shareowner return performance graph the follo...
# 4   [during fiscal 2013 , we entered into an asr w...
# ..                                                ...
# 95  [future impairments would be recorded in incom...
# 96  [stockholder return performance graph the foll...
# 97  [table of contents research and development ex...
# 98  [of exercise for stock options exercised or at...
# 99  [stock performance graph the following graph s...
#
#                                              response reference  faithfulness  \
# 0   The net cash from operating activities increas...     14.1%      0.000000
# 1   The context does not provide information about...      1.3%      1.000000
# 2   Net sales decreased from $7,983 million in 200...      -32%      0.333333
# 3   The cumulative return for United Parcel Servic...   -26.16%      1.000000
# 4   As of December 31, 2010, there were 2,530,454 ...     70.1%      1.000000
# ..                                                ...       ...           ...
# 95  The total segment revenues in 2001 were $9.3 b...       9.3      1.000000
# 96  The rate of return for an investment in the NA...      6.2%      0.666667
# 97  The context does not provide information regar...      273%      1.000000
# 98  The context does not provide the 2014 closing ...      56.5      1.000000
# 99  The cumulative total shareholder return on DIS...     2.53%      1.000000
#
#     answer_relevancy  context_precision  context_recall  \
# 0           0.978857               1.00             0.0
# 1           0.000000               0.00             0.0
# 2           0.995026               1.00             0.0
# 3           0.955393               1.00             0.0
# 4           0.949249               0.25             0.0
# ..               ...                ...             ...
# 95          0.927346               1.00             1.0
# 96          0.975986               1.00             0.0
# 97          0.000000               0.00             0.0
# 98          0.000000               0.00             0.0
# 99          0.970605               1.00             0.0
#
#     context_entity_recall  semantic_similarity  answer_correctness
# 0                     0.0             0.767518            0.566879
# 1                     0.0             0.774300            0.193575
# 2                     0.0             0.810555            0.577639
# 3                     0.0             0.774348            0.568587
# 4                     0.0             0.759034            0.564759
# ..                    ...                  ...                 ...
# 95                    0.0             0.774776            0.693694
# 96                    0.0             0.766229            0.191557
# 97                    0.0             0.768890            0.192222
# 98                    0.0             0.742845            0.185711
# 99                    0.0             0.773279            0.568320
#
# [100 rows x 11 columns]
#
# Mean Scores:
# faithfulness             0.752837
# answer_relevancy         0.556623
# context_precision        0.459167
# context_recall           0.028090
# context_entity_recall    0.000000
# semantic_similarity      0.768783
# answer_correctness       0.338843
# dtype: float64
#
# Detailed Comparison:
#
# Example 1:
# Query: what was the percentage change in the net cash from operating activities from 2008 to 2009
# Ground Truth: 14.1%
# Generated: The net cash from operating activities increased from $174,247 in 2008 to $206,588 in 2009. This represents a percentage change of approximately 18.5%.
# --------------------------------------------------------------------------------
#
# Example 2:
# Query: what was the percent of the growth in the revenues from 2007 to 2008
# Ground Truth: 1.3%
# Generated: The context does not provide information about revenues from 2007 to 2008, so the percent of growth in revenues during that period cannot be determined.
# --------------------------------------------------------------------------------
#
# Example 3:
# Query: what was the percentage change in net sales from 2000 to 2001?
# Ground Truth: -32%
# Generated: Net sales decreased from $7,983 million in 2000 to $5,363 million in 2001, resulting in a percentage change of approximately -32.5%.
# --------------------------------------------------------------------------------
#
# Example 4:
# Query: what was the difference in percentage cumulative return on investment for united parcel service inc . compared to the s&p 500 index for the five year period ended 12/31/09?
# Ground Truth: -26.16%
# Generated: The cumulative return for United Parcel Service, Inc. was $75.95, while the S&P 500 Index was $102.11 at the end of the five-year period. The difference in percentage cumulative return is approximately -25.8%.
# --------------------------------------------------------------------------------
#
# Example 5:
# Query: what portion of the total shares subject to outstanding awards is under the 2009 global incentive plan?
# Ground Truth: 70.1%
# Generated: As of December 31, 2010, there were 2,530,454 shares subject to outstanding awards under the 2009 Global Incentive Plan. There were no shares available for awards under the 2004 Stock Incentive Plan.
# --------------------------------------------------------------------------------
#
# Example 6:
# Query: what was the percentage increase in litigation reserves in 2012?
# Ground Truth: 15.6%
# Generated: The context does not provide information about litigation reserves specifically for 2012, so the percentage increase cannot be determined.
# --------------------------------------------------------------------------------
#
# Example 7:
# Query: what portion of total obligations are due within the next 3 years?
# Ground Truth: 22.99%
# Generated: The portion of total obligations due within the next 3 years is $72,890 million, which includes $27,729 million due in less than 1 year and $45,161 million due in 1-3 years.
# --------------------------------------------------------------------------------
#
# Example 8:
# Query: for the years ended december 31 , 2013 , 2012 and 2011 , what was the total in millions capitalized to assets associated with compensation expense related to long-term compensation plans , restricted stock and stock options?\\n
# Ground Truth: 12
# Generated: For the years ended December 31, 2013, 2012, and 2011, approximately $4.5 million, $4.1 million, and $3.4 million, respectively, was capitalized to assets associated with compensation expense related to long-term compensation plans, restricted stock, and stock options.
# --------------------------------------------------------------------------------
#
# Example 9:
# Query: what is the percent change in net revenue between 2007 and 2008?
# Ground Truth: 2.4%
# Generated: The context does not provide information about net revenue for the years 2007 and 2008, so the percent change cannot be determined.
# --------------------------------------------------------------------------------
#
# Example 10:
# Query: what portion of the authorized shares of class b common stock is outstanding as of december 31 , 2017?
# Ground Truth: 56.6%
# Generated: As of December 31, 2017, there were 707 million shares of class B common stock outstanding out of the 1.25 billion authorized shares. This means approximately 56.56% of the authorized class B common stock is outstanding.
# --------------------------------------------------------------------------------
#
# Example 11:
# Query: what was the 5 year return of the kbw bank index?
# Ground Truth: 158.82%
# Generated: The five-year return of the KBW Bank Index from December 31, 2011, to December 31, 2016, was $258.82, starting from an initial investment of $100. This represents a cumulative return of 158.82%.
# --------------------------------------------------------------------------------
#
# Example 12:
# Query: what is the percentage change in the balance of asset allocation from 2016 to 2017?
# Ground Truth: 11.2%
# Generated: The balance of asset allocation increased from $176,675 million in 2016 to $196,545 million in 2017. This represents a percentage change of approximately 11.5%.
# --------------------------------------------------------------------------------
#
# Example 13:
# Query: between 2015 and 2013 what was the average compensation expense related to the issuing of the stock award in millions
# Ground Truth: 40.3
# Generated: The average compensation expense related to stock awards from 2013 to 2015 was $40 million. This is calculated from $44 million in 2013, $34 million in 2014, and $43 million in 2015.
# --------------------------------------------------------------------------------
#
# Example 14:
# Query: what is the total expected payments for principal of long- term debt , including capital leases in the next 36 months?
# Ground Truth: 594840
# Generated: The total expected payments for principal of long-term debt in the next 36 months is $1,824 million, which includes $536 million due in less than 1 year and $1,288 million due in 1-3 years.
# --------------------------------------------------------------------------------
#
# Example 15:
# Query: what is the percent change in net loss on disposal of assets between 2004 and 2005?
# Ground Truth: 700%
# Generated: The net loss on disposal of assets increased from $43,000 in 2004 to $344,000 in 2005. This represents a percent change of approximately 700%.
# --------------------------------------------------------------------------------
#
# Example 16:
# Query: how much higher are the returns of the s&p 500 in the same period ( 2008-2013 ) ? as a percentage .
# Ground Truth: 30%
# Generated: The S&P 500 had a cumulative return of approximately 47% from 2008 to 2013, while UPS had a return of about 11%. Therefore, the S&P 500's returns were approximately 36% higher than UPS's during that period.
# --------------------------------------------------------------------------------
#
# Example 17:
# Query: what is the percentage change in standardized rwas in 2014?
# Ground Truth: -1.2%
# Generated: The percentage change in standardized RWAs from 2013 to 2014 is a decrease of approximately 1.0%. Standardized RWAs were $635,092 million in 2013 and $627,444 million in 2014.
# --------------------------------------------------------------------------------
#
# Example 18:
# Query: what percentage did the balance increase from 2007 to 2009?
# Ground Truth: 83.6%
# Generated: The context does not provide specific balance figures for 2007 or 2009, so the percentage increase cannot be calculated. Therefore, the answer cannot be determined from the given information.
# --------------------------------------------------------------------------------
#
# Example 19:
# Query: what is the percentual decrease observed in the future minimum rental payments during 2008 and 2009?
# Ground Truth: 13.25%
# Generated: The future minimum rental payments decreased from $317 million in 2008 to $275 million in 2009, which is a decrease of approximately 13.25%.
# --------------------------------------------------------------------------------
#
# Example 20:
# Query: what was the percentage change of total debt from 2001 to 2002?
# Ground Truth: -57%
# Generated: The total debt percentage change from 2001 to 2002 cannot be determined from the provided context, as specific total debt figures for 2001 are not included. Only the total debt at the end of 2005 and 2004 is mentioned.
# --------------------------------------------------------------------------------
#
# Example 21:
# Query: what is the total revenue for the fiscal year of 2015?
# Ground Truth: 7020
# Generated: The total revenue for the fiscal year of 2015 is $7,020 million, calculated by summing the quarterly sales and service revenues: $1,570M + $1,745M + $1,800M + $1,905M.
# --------------------------------------------------------------------------------
#
# Example 22:
# Query: what was the percentage change in revenues for investments in 50% ( 50 % ) or less owned investments accounted for using the equity method between 2000 and 2001?
# Ground Truth: -2%
# Generated: The context does not provide information regarding the percentage change in revenues for investments in 50% or less owned investments accounted for using the equity method between 2000 and 2001. Therefore, the answer cannot be determined from the given context.
# --------------------------------------------------------------------------------
#
# Example 23:
# Query: how many square feet are owned by the company?
# Ground Truth: 377000
# Generated: The company owns approximately 1,000,000 square feet across various locations, including 514,000 square feet in New Haven, Connecticut, and 160,000 square feet in Dublin, Ireland, among others.
# --------------------------------------------------------------------------------
#
# Example 24:
# Query: considering the years 2017 and 2018 , what is the percentual increase observed in capital expenditures used for continuing operations?
# Ground Truth: 31.14%
# Generated: The context does not provide information about capital expenditures for the years 2017 and 2018, so the percentual increase cannot be determined.
# --------------------------------------------------------------------------------
#
# Example 25:
# Query: what was the percentage decline in the total restricted cash and marketable securities from 2011 to 2012
# Ground Truth: -13.4%
# Generated: The context does not provide information about restricted cash and marketable securities for the years 2011 and 2012, so the percentage decline cannot be determined.
# --------------------------------------------------------------------------------
#
# Example 26:
# Query: what was the percent change in the value of commercial paper outstanding between 2010 and 2011?
# Ground Truth: 18%
# Generated: The context does not provide specific values for commercial paper outstanding in 2010 and 2011, so the percent change cannot be determined. Therefore, the answer is not available based on the provided information.
# --------------------------------------------------------------------------------
#
# Example 27:
# Query: what was the growth rate of the s&p 500 index from 2011 to 2016
# Ground Truth: 98.2%
# Generated: The S&P 500 index grew from $100 in 2011 to $163 in 2015, resulting in a growth rate of 63%. However, the data does not provide information for 2016, so the growth rate cannot be calculated for that year.
# --------------------------------------------------------------------------------
#
# Example 28:
# Query: what was the firm's average sum of contractual principal , interest and fees in 2008 and 2009?
# Ground Truth: $ 110774.5 million
# Generated: The context does not provide specific information about the firm's average sum of contractual principal, interest, and fees for 2008 and 2009. Therefore, I cannot answer the question based on the provided context.
# --------------------------------------------------------------------------------
#
# Example 29:
# Query: what is the percentage change in staff number in 2013?
# Ground Truth: 1.5%
# Generated: The percentage change in staff number in 2013 is approximately 1.55% higher than in 2012, increasing from 32,400 to 32,900.
# --------------------------------------------------------------------------------
#
# Example 30:
# Query: in 2019 what was the net change in cash in millions
# Ground Truth: -489.2
# Generated: The net change in cash in 2019 was a decrease of $2,608.6 million, calculated as $151.6 million in cash and cash equivalents at the end of 2019 minus $636.8 million at the end of 2018.
# --------------------------------------------------------------------------------
#
# Example 31:
# Query: what is the growth rate in the average price of the purchased shares from october to november 2014?
# Ground Truth: 6.1%
# Generated: The context does not provide specific share prices for October and November 2014, so the growth rate cannot be determined. Therefore, the answer is not available based on the provided information.
# --------------------------------------------------------------------------------
#
# Example 32:
# Query: what is the roi of an investment in the o'reilly automotive inc . from 2010 to 2011?
# Ground Truth: 32%
# Generated: The ROI of an investment in O'Reilly Automotive, Inc. from 2010 to 2011 is 32% (calculated as ($132 - $100) / $100).
# --------------------------------------------------------------------------------
#
# Example 33:
# Query: what is the percent increase in cash and cash equivalents from year 2009 to 2010?
# Ground Truth: 24.4%
# Generated: The cash and cash equivalents increased from $364,221 in 2009 to $453,257 in 2010. This represents a percent increase of approximately 24.5%.
# --------------------------------------------------------------------------------
#
# Example 34:
# Query: by what percent did effects of foreign operations decrease from 2002 to 2004?
# Ground Truth: -76.8%
# Generated: The effects of foreign operations decreased from 5.6% in 2002 to 1.3% in 2004, a decrease of 4.3 percentage points. This represents a decrease of approximately 76.8%.
# --------------------------------------------------------------------------------
#
# Example 35:
# Query: what was the percentage change of the net revenue in 2010
# Ground Truth: 7.61%
# Generated: The net revenue increased by 52% in 2010 compared to 2009. This significant growth contributed to the decline of R&D expense as a percentage of net sales.
# --------------------------------------------------------------------------------
#
# Example 36:
# Query: what was the percentage change in industry segment operating profits from 2006 to 2007?
# Ground Truth: 17%
# Generated: The percentage change in industry segment operating profits from 2006 to 2007 was approximately 16.8%, increasing from $2,074 million to $2,423 million.
# --------------------------------------------------------------------------------
#
# Example 37:
# Query: what was the percentage increase in the cash and cash equivalents from 2005 to 2006
# Ground Truth: -16.6%
# Generated: The context does not provide information about cash and cash equivalents for the years 2005 and 2006, so the percentage increase cannot be determined.
# --------------------------------------------------------------------------------
#
# Example 38:
# Query: by how much did asset retirement obligations decrease from 2007 to 2008?
# Ground Truth: -14.9%
# Generated: Asset retirement obligations decreased by $169 million from 2007 to 2008, from $1,134 million to $965 million.
# --------------------------------------------------------------------------------
#
# Example 39:
# Query: north american printing papers net sales where what percent of total printing paper sales in 2009?
# Ground Truth: 49%
# Generated: North American printing papers net sales in 2009 were $2.8 billion out of total printing paper sales of $5.68 billion, which is approximately 49.4%.
# --------------------------------------------------------------------------------
#
# Example 40:
# Query: by how much did total other income and expense decrease from 2008 to 2009?
# Ground Truth: 47.4%
# Generated: Total other income and expense decreased by $294 million from 2008 to 2009, from $620 million in 2008 to $326 million in 2009.
# --------------------------------------------------------------------------------
#
# Example 41:
# Query: what was the percentage chaning in the total fair value of restricted stock and performance awards vested from 2016 to 2017?
# Ground Truth: 69%
# Generated: The total fair value of restricted stock and performance awards vested increased from $28.8 million in 2016 to $33.7 million in 2017. This represents a percentage change of approximately 17.0%.
# --------------------------------------------------------------------------------
#
# Example 42:
# Query: what are the total pre-tax catastrophe losses in the last three years?
# Ground Truth: 1905.4
# Generated: The total pre-tax catastrophe losses in the last three years (2011, 2012, and 2013) are $1,300.4 million + $410.0 million + $195.0 million, totaling $1,905.4 million.
# --------------------------------------------------------------------------------
#
# Example 43:
# Query: what percentage where north american consumer packaging net sales of total consumer packaging sales in 2011?
# Ground Truth: 67%
# Generated: North American consumer packaging net sales in 2011 were $2.5 billion, while total consumer packaging sales were $3.710 billion. Therefore, North American consumer packaging net sales were approximately 67.3% of total consumer packaging sales in 2011.
# --------------------------------------------------------------------------------
#
# Example 44:
# Query: what was the percent of the growth in the revenues from 2005 to 2006
# Ground Truth: 45.3%
# Generated: The context does not provide information about revenues from 2005 to 2006, so the percent of growth in revenues during that period cannot be determined.
# --------------------------------------------------------------------------------
#
# Example 45:
# Query: what was the percentage change in rental expenses from 2017 to 2018?
# Ground Truth: 21%
# Generated: The context does not provide information regarding rental expenses or their percentage change from 2017 to 2018. Therefore, the percentage change in rental expenses cannot be determined.
# --------------------------------------------------------------------------------
#
# Example 46:
# Query: what was the percent of the growth in the recurring tenant improvements from 2006 to 2007
# Ground Truth: 8.1%
# Generated: The recurring tenant improvements increased from $41,895 in 2006 to $45,296 in 2007, which is a growth of approximately 9.5%. This is calculated as ((45,296 - 41,895) / 41,895) * 100.
# --------------------------------------------------------------------------------
#
# Example 47:
# Query: what was the percentage cumulative total shareholder return on disca common stock from september 18 , 2008 to december 31 , 2012?
# Ground Truth: 359.67%
# Generated: The cumulative total shareholder return on DISCA common stock from September 18, 2008, to December 31, 2012, was approximately 359.67%. This is calculated from an initial investment of $100 growing to $459.67.
# --------------------------------------------------------------------------------
#
# Example 48:
# Query: what was the percentage change in the net cash used in investing activities from 2006 to 2007
# Ground Truth: -6.4%
# Generated: The net cash used in investing activities decreased from $(1,460) million in 2006 to $(1,367) million in 2007. This represents a percentage change of approximately 6.36% decrease.
# --------------------------------------------------------------------------------
#
# Example 49:
# Query: if the 2003 growth rate is the same as 2002 , what would 2003 gas transmission throughput be in bcf?\\n
# Ground Truth: 645
# Generated: The context does not provide specific information about gas transmission throughput for 2002 or any growth rates. Therefore, it is not possible to determine the 2003 gas transmission throughput in bcf based on the given information.
# --------------------------------------------------------------------------------
#
# Example 50:
# Query: what was the percentage change in revenues between 2005 and 2006?
# Ground Truth: 45%
# Generated: The context does not provide information about revenues for the years 2005 and 2006, so the percentage change in revenues between those years cannot be determined.
# --------------------------------------------------------------------------------
#
# Example 51:
# Query: by how much did total revenues increase from 2010 to 2011?
# Ground Truth: 25.4%
# Generated: The context does not provide information about total revenues for 2011, so it is not possible to determine the increase from 2010 to 2011. Therefore, the answer cannot be provided based on the given context.
# --------------------------------------------------------------------------------
#
# Example 52:
# Query: what is the percentage change in total dividends paid per share from 2017 to 2018?
# Ground Truth: 9.9%
# Generated: The context does not provide information regarding total dividends paid per share for the years 2017 and 2018, so the percentage change cannot be determined.
# --------------------------------------------------------------------------------
#
# Example 53:
# Query: what was the percentage change in the research and development costs from 2015 to 2016
# Ground Truth: -34.4%
# Generated: The context does not provide information about research and development costs for the years 2015 and 2016, so the percentage change cannot be determined.
# --------------------------------------------------------------------------------
#
# Example 54:
# Query: what is the percentage change in net reserves from 2011 to 2012?
# Ground Truth: -11.3%
# Generated: The context does not provide specific information about net reserves for 2011 and 2012, so the percentage change cannot be determined.
# --------------------------------------------------------------------------------
#
# Example 55:
# Query: what is the growth rate in the net income from 2011 to 2012?
# Ground Truth: -78.8%
# Generated: The context does not provide information on net income for the years 2011 and 2012, so the growth rate cannot be determined.
# --------------------------------------------------------------------------------
#
# Example 56:
# Query: what is the percentage change in the weight of smokeless products in operating income from 2015 to 2016?
# Ground Truth: 2.3%
# Generated: The percentage change in the weight of smokeless products in operating income from 2015 to 2016 is approximately 2.4% (from 12.8% in 2015 to 13.1% in 2016). This is calculated as (13.1 - 12.8) / 12.8 * 100.
# --------------------------------------------------------------------------------
#
# Example 57:
# Query: what is the percentage change in the average total short-duration advances from 2013 to 2014?
# Ground Truth: 3.1%
# Generated: The average total short-duration advances increased from $3,749 million in 2013 to $3,867 million in 2014, which is a percentage change of approximately 3.14%.
# --------------------------------------------------------------------------------
#
# Example 58:
# Query: by what percentage did asset retirement obligations increase from 2008 to 2009?
# Ground Truth: 14.2%
# Generated: Asset retirement obligations increased from $965 million in 2008 to $1,102 million in 2009, which is an increase of approximately 14.2%.
# --------------------------------------------------------------------------------
#
# Example 59:
# Query: what percent of printing papers sales in 2006 was from north american printing papers net sales?
# Ground Truth: 66%
# Generated: North American printing papers net sales in 2006 were $4.4 billion, while total printing papers sales were $6.7 billion. Therefore, approximately 65.67% of printing papers sales in 2006 came from North American printing papers net sales.
# --------------------------------------------------------------------------------
#
# Example 60:
# Query: by how much did american airlines group inc . common stock out preform the s&p 500 index over the 4 year period?
# Ground Truth: 48%
# Generated: American Airlines Group Inc. common stock increased from $100 to $175, while the S&P 500 index increased from $100 to $113 over the same period. Therefore, American Airlines outperformed the S&P 500 by $62.
# --------------------------------------------------------------------------------
#
# Example 61:
# Query: what is the short-term debt as a percent of long-term debt , in 2019?
# Ground Truth: 1.80%
# Generated: In 2019, short-term borrowings were $58.2 million and long-term debt was $2,907.3 million. Therefore, short-term debt as a percent of long-term debt is approximately 2.0%.
# --------------------------------------------------------------------------------
#
# Example 62:
# Query: how much , in billions , was spent purchasing common stock under the programs from 2016-2018?
# Ground Truth: 4.1
# Generated: The context does not provide information about the amount spent on purchasing common stock under the programs from 2016-2018. Therefore, the answer cannot be determined from the given context.
# --------------------------------------------------------------------------------
#
# Example 63:
# Query: what is the percentage increase in the balance of goodwill from 2017 to 2018?
# Ground Truth: -0.6%
# Generated: The balance of goodwill increased from $666,009 in 2017 to $662,272 in 2018, which is a decrease, not an increase. Therefore, the percentage change is negative, calculated as \((-3,737 / 666,009) \times 100 \approx -0.56\%\).
# --------------------------------------------------------------------------------
#
# Example 64:
# Query: what is actual operating cash flow reported for 2011?
# Ground Truth: 3.129
# Generated: The context does not provide information on the actual operating cash flow reported for 2011. It only includes data for fiscal years ending in 2010, 2009, and 2008.
# --------------------------------------------------------------------------------
#
# Example 65:
# Query: what is the percentage change in benefits obligations from 2018 to 2019?
# Ground Truth: 19.4%
# Generated: The benefit obligations in 2018 were $162 million, and in 2019, they were $25 million. The percentage change is approximately a decrease of 84.6%.
# --------------------------------------------------------------------------------
#
# Example 66:
# Query: what is the growth rate of interest income from 2013 to 2014?
# Ground Truth: 10.9%
# Generated: The context does not provide information about net interest income for 2014, so the growth rate from 2013 to 2014 cannot be determined.
# --------------------------------------------------------------------------------
#
# Example 67:
# Query: what is the percentage change in the cash dividends received by the company in 2012 compare to 2011?
# Ground Truth: 6.4%
# Generated: The context does not provide any information regarding cash dividends received by the company in 2011 or 2012. Therefore, the percentage change cannot be determined.
# --------------------------------------------------------------------------------
#
# Example 68:
# Query: what is the growth rate in the share-based compensation expense from 2014 to 2015?
# Ground Truth: -29.2%
# Generated: The share-based compensation expense increased from $29.8 million in 2014 to $21.1 million in 2015. This represents a decrease, not a growth rate.
# --------------------------------------------------------------------------------
#
# Example 69:
# Query: what percentage of contractual obligations for future payments under existing debt and lease commitments and purchase obligations at december 31 , 2012 is short term for the year 2014?
# Ground Truth: 58%
# Generated: The context does not provide specific data for December 31, 2012, or for the year 2014 regarding contractual obligations. Therefore, it is not possible to determine the percentage of short-term obligations for those years based on the provided information.
# --------------------------------------------------------------------------------
#
# Example 70:
# Query: did 2015 adjusted ebitda increase more than 2015 actual ebitda?
# Ground Truth: no
# Generated: No, adjusted EBITDA in 2015 was $1,018.5 million, which is less than the actual EBITDA of $1,033.9 million for the same year.
# --------------------------------------------------------------------------------
#
# Example 71:
# Query: what is the growth rate in net sales for is&gs in 2011?
# Ground Truth: -5.4%
# Generated: The context does not provide specific information about the growth rate in net sales for is&gs in 2011. Therefore, the growth rate cannot be determined from the given information.
# --------------------------------------------------------------------------------
#
# Example 72:
# Query: what is the percentage change in nonrecurring losses from 2012 to 2013?
# Ground Truth: 11.8%
# Generated: The context does not provide information about nonrecurring losses for the years 2012 and 2013, so the percentage change cannot be determined.
# --------------------------------------------------------------------------------
#
# Example 73:
# Query: what is the growth rate in net revenue in 2003 for entergy corporation?
# Ground Truth: 0.1%
# Generated: The net revenue for Entergy Corporation in 2003 was $4,214.5 million, compared to $4,209.6 million in 2002, indicating a growth of approximately 0.12%. This growth was primarily due to base rate increases and deferred fuel cost revisions.
# --------------------------------------------------------------------------------
#
# Example 74:
# Query: what is the percent change in net revenue from 2003 to 2004?
# Ground Truth: 14.7%
# Generated: The context does not provide information about net revenue for the years 2003 and 2004, so the percent change cannot be determined.
# --------------------------------------------------------------------------------
#
# Example 75:
# Query: what was the percentage gain on the sale of starter brand business?
# Ground Truth: 91%
# Generated: The context does not provide any information regarding the percentage gain on the sale of the starter brand business. Therefore, the answer cannot be determined from the given context.
# --------------------------------------------------------------------------------
#
# Example 76:
# Query: what was the difference in percentage cumulative total shareowners 2019 returns for united parcel service inc . versus the standard & poor 2019s 500 index for the five years ended 12/31/10?
# Ground Truth: -1.42%
# Generated: The cumulative total return for United Parcel Service, Inc. was $110.57, while for the S&P 500 Index it was $111.99. The difference in percentage is approximately -1.27%.
# --------------------------------------------------------------------------------
#
# Example 77:
# Query: what was the percentage cumulative total shareholder return on disca for the five year period ended december 21 , 2013?
# Ground Truth: 502.08%
# Generated: The cumulative total shareholder return on DISCA for the five-year period ended December 31, 2013, was 538.56%. This is calculated from an initial investment of $100 growing to $638.56.
# --------------------------------------------------------------------------------
#
# Example 78:
# Query: what is the percentage difference in the number of shares to be issued if the stock price closes at $ 11 compared to if it closes at $ 20?
# Ground Truth: 278%
# Generated: The context does not provide information regarding the number of shares to be issued or the stock prices of $11 and $20. Therefore, I cannot determine the percentage difference based on the given context.
# --------------------------------------------------------------------------------
#
# Example 79:
# Query: what is the growth rate in operating profit for mst in 2012?
# Ground Truth: 14.3%
# Generated: The growth rate in operating profit for MST in 2012 was 14%, increasing by $92 million compared to 2011.
# --------------------------------------------------------------------------------
#
# Example 80:
# Query: what was the percentage change in rent expenses included in selling , general and administrative expense from 2014 to 2015?
# Ground Truth: 41%
# Generated: The rent expense included in selling, general and administrative expense increased from $59.0 million in 2014 to $83.0 million in 2015, which is a percentage change of approximately 40.68%.
# --------------------------------------------------------------------------------
#
# Example 81:
# Query: in billions , what would 2018 total operating revenues have been without the mexico business?
# Ground Truth: 20.332
# Generated: The context does not provide specific information about the total operating revenues for 2018 or the impact of the Mexico business on those revenues. Therefore, it is not possible to determine the total operating revenues without the Mexico business based on the given context.
# --------------------------------------------------------------------------------
#
# Example 82:
# Query: how much did the company 2019s valuation allowance decrease from 2010 to 2012?
# Ground Truth: -23.8%
# Generated: The context does not provide information regarding the company's valuation allowance or any changes to it from 2010 to 2012. Therefore, I cannot answer the question based on the given context.
# --------------------------------------------------------------------------------
#
# Example 83:
# Query: what is the amount of cash raised from the issuance of shares during 2015 , in millions?
# Ground Truth: 4.5
# Generated: The context does not provide any information about cash raised from the issuance of shares during 2015. Therefore, the amount is not specified.
# --------------------------------------------------------------------------------
#
# Example 84:
# Query: what was the percentage change in the net cash used in financing activities from 2004 to 2005
# Ground Truth: 45.2%
# Generated: The context does not provide information about net cash used in financing activities for the years 2004 and 2005, so the percentage change cannot be determined.
# --------------------------------------------------------------------------------
#
# Example 85:
# Query: what is the growth rate in sublease revenues from 2007 to 2008?
# Ground Truth: -7.8%
# Generated: The sublease revenues increased from $1.2 million in 2007 to $2.7 million in 2008. This represents a growth rate of approximately 125%.
# --------------------------------------------------------------------------------
#
# Example 86:
# Query: what is the percentage of total debt from 2014-2015 that was long-term debt?
# Ground Truth: 92.5%
# Generated: The context does not provide specific total debt figures for 2014 and 2015, so the percentage of total debt that was long-term debt cannot be calculated. Therefore, the answer cannot be determined based on the provided information.
# --------------------------------------------------------------------------------
#
# Example 87:
# Query: what is the percentage change in the balance of alternative assets from 2011 to 2012?
# Ground Truth: 4.6%
# Generated: The balance of alternative assets increased from $104.9 billion in 2011 to $109.8 billion in 2012, reflecting a percentage change of approximately 5%.
# --------------------------------------------------------------------------------
#
# Example 88:
# Query: what percentage of total debt is from long-term debt , from 2013-2014?
# Ground Truth: 81.09
# Generated: In 2014, long-term debt was $9.31 billion out of total debt of $15.91 billion, which is approximately 58.4%. In 2013, long-term debt was $8.42 billion out of total debt of $13.78 billion, which is approximately 61.1%.
# --------------------------------------------------------------------------------
#
# Example 89:
# Query: what was the average net interest margin for 2008 and for 2007?
# Ground Truth: 3.2%
# Generated: The average net interest margin for 2008 was 3.37% and for 2007 it was 3.00%.
# --------------------------------------------------------------------------------
#
# Example 90:
# Query: what percentage of total shares purchased was purchased in december?
# Ground Truth: 36.55%
# Generated: The total number of shares purchased in December was 365,683 out of 1,269,242 total shares. This represents approximately 28.8% of the total shares purchased.
# --------------------------------------------------------------------------------
#
# Example 91:
# Query: in 2014 what was the combined total experience loss
# Ground Truth: 3633
# Generated: The context does not provide specific information about the combined total experience loss for 2014. Therefore, it cannot be determined from the given information.
# --------------------------------------------------------------------------------
#
# Example 92:
# Query: what is the total value of repurchased shares during october 2012 , in millions?
# Ground Truth: 78.7
# Generated: The total value of repurchased shares during October 2012 is $286 million.
# --------------------------------------------------------------------------------
#
# Example 93:
# Query: what was the average net interest margin in% ( in % ) for 2009 and 2008.?
# Ground Truth: 3.6
# Generated: The average net interest margin was 3.82% for 2009 and 3.37% for 2008.
# --------------------------------------------------------------------------------
#
# Example 94:
# Query: how is the treasury stock affected after the stock repurchases in the last three months of 2016 , ( in millions ) ?
# Ground Truth: 110.3
# Generated: The context does not provide information about stock repurchases in the last three months of 2016, so I cannot answer the question.
# --------------------------------------------------------------------------------
#
# Example 95:
# Query: what is the net income margin for 2018?
# Ground Truth: 3.3%
# Generated: The context does not provide information about the net income margin for 2018. Therefore, it cannot be determined from the given text.
# --------------------------------------------------------------------------------
#
# Example 96:
# Query: what were 2001 total segment revenues in billions?
# Ground Truth: 9.3
# Generated: The total segment revenues in 2001 were $9.3 billion. This represents a 24% increase from $7.5 billion in 2000.
# --------------------------------------------------------------------------------
#
# Example 97:
# Query: what is the rate of return of an investment in nasdaq composite from the end of the year in 2015 to the end of the year in 2016?
# Ground Truth: 6.2%
# Generated: The rate of return for an investment in the NASDAQ Composite from the end of 2015 to the end of 2016 is approximately 8.5%, calculated from $200.32 to $216.54. This represents an increase of $16.22 on an initial investment of $200.32.
# --------------------------------------------------------------------------------
#
# Example 98:
# Query: what was the percentage change in the reserve for product warranties from december 31 2006 to december 30 2007?
# Ground Truth: 273%
# Generated: The context does not provide information regarding the reserve for product warranties or any percentage change related to it from December 31, 2006, to December 30, 2007. Therefore, the percentage change cannot be determined.
# --------------------------------------------------------------------------------
#
# Example 99:
# Query: with 2014 closing stock price , what is the total value of the award for the additional shares , ( in millions ) ?
# Ground Truth: 56.5
# Generated: The context does not provide the 2014 closing stock price or the number of additional shares awarded, so the total value of the award cannot be calculated. Therefore, the answer cannot be determined based on the provided information.
# --------------------------------------------------------------------------------
#
# Example 100:
# Query: what was the percentage cumulative total shareholder return on disca common stock from september 18 , 2008 to december 31 , 2008?
# Ground Truth: 2.53%
# Generated: The cumulative total shareholder return on DISCA common stock from September 18, 2008, to December 31, 2008, was approximately 2.53%. This is calculated from an initial investment of $100, which grew to $102.53.
# --------------------------------------------------------------------------------
